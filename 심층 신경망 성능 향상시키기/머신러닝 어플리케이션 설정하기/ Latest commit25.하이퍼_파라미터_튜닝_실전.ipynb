# %% [markdown]
# <a href="https://colab.research.google.com/github/audrb1999/ML-DL-Study/blob/main/%EC%8B%AC%EC%B8%B5%20%EC%8B%A0%EA%B2%BD%EB%A7%9D%20%EC%84%B1%EB%8A%A5%20%ED%96%A5%EC%83%81%EC%8B%9C%ED%82%A4%EA%B8%B0/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%20%EC%96%B4%ED%94%8C%EB%A6%AC%EC%BC%80%EC%9D%B4%EC%85%98%20%EC%84%A4%EC%A0%95%ED%95%98%EA%B8%B0/%20Latest%20commit25.%ED%95%98%EC%9D%B4%ED%8D%BC_%ED%8C%8C%EB%9D%BC%EB%AF%B8%ED%84%B0_%ED%8A%9C%EB%8B%9D_%EC%8B%A4%EC%A0%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #하이퍼파라미터 튜닝 실전

# %% [markdown]
# 탐색을 어떻게 할 수 있는지 몇 가지의 팁
#
# 딥러닝은 매우 많은 분야에서 활용되고 있습니다.
#
# 그러다보니 분야마다 중요한 하이퍼파라매터가 달라서 한 어플리케이션 분야에서 얻은 하이퍼피라매터에 대한 직관이 다른 영역에서 쓰일 수도 있지만 사용되지 않을 수도있습니다.

# %% [markdown]
# 서로 다른 어플리케이션 영역 간에 공유되는 것들이 존재하는데
#
# 예를 들어 컴퓨터 비전 커뮤니티에서 발전된 컨브넷이나 레스넷등이 있는데 강의 뒷부분에서 나옵니다.
#
# 이것들이 음성에 잘 적용되고 있습니다, 그리고 이 음성에서 발전된 아이디어들이 자연어 처리에서도 잘 적용되고 있습니다.
#
# 즉 딥러닝 분야의 사람들이 다른 영역에서 영감을 얻기위해 그 분야의 논문들을 읽고 있습니다.
#
# 하지만 하이퍼파라미터를 찾는 과정은 다른 분야의 논문을 통해서 얻을 수 없습니다.

# %% [markdown]
# 로지스틱 문제하나만 보더라도 데이터가 바뀌거나 알고리즘이 업그레이드 되면 우리가 찾은 하이퍼파라미터가 녹슬게 됩니다. (다시 시도해서 현재에 가장 알맞은 하이퍼파라미터를 찾아야함)

# %% [markdown]
# ## 하이퍼파라미터 찾기

# %% [markdown]
# 1. 모델 돌보기
#
# 데이터는 방대하지만 CPU나 GPU 등 컴퓨터 자원이 많이 필요하지 않아서 적은 숫자의 모델을 한번에 학습시킬 수 있을 때 사용합니다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 매일 모델의 학습이 제대로 이루어지는지 확인하고 제대로 이루어진다면 모멘텀을 약간 올리거나 학습 속도를 올리는 등 사람이 일일히 모델을 돌보면 학습시키는 것
#
# - 여러 모델을 동시에 학습시킬 때, 컴퓨터 자원이 충분하지 않을 떄 사용
#
# - 컴퓨터 자원대신 인적자원을 사용하는 느낌?
#
# 판다 접근, 판다는 한번에 하나의 새끼만을 가져 하나의 아기판다에 많은 노력을 기울임

# %% [markdown]
# 2. 여러 모델을 함께 학습시키는 것
#
# 이 방법을 사용하면 여러 하이퍼파라미터를 시험해볼 수 있다
#
# 다음과 같이 하나의 모델이 아닌 여러 모델을 학습
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 캐비어 전략, 하나의 많은 전략보단 하나 또는 그 이상이 더 잘 살아남기를 바라며 그저 지켜보는 것!

# %% [markdown]
# - 두 접근 중에 뭘 선택할지는 컴퓨터 자원의 양과 함수 관계에 있습니다.
#
# 컴퓨터 자원이 충분하다면 캐비어로 다양한 하이퍼파라미터 시험
#
# 하지만 온라인 광고나 컴퓨터 비전 어플리케이션 등 많은 데이터가 쓰이는 곳에서는 학습시키고자 하는 모델이 너무 커서 한 번에 여러 모델을 학습시키기 어렵습니다.
