# %% [markdown]
# <a href="https://colab.research.google.com/github/audrb1999/ML-DL-Study/blob/main/%EC%8B%AC%EC%B8%B5%20%EC%8B%A0%EA%B2%BD%EB%A7%9D%20%EC%84%B1%EB%8A%A5%20%ED%96%A5%EC%83%81%EC%8B%9C%ED%82%A4%EA%B8%B0/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%20%EC%96%B4%ED%94%8C%EB%A6%AC%EC%BC%80%EC%9D%B4%EC%85%98%20%EC%84%A4%EC%A0%95%ED%95%98%EA%B8%B0/08.%EB%8B%A4%EB%A5%B8_%EC%A0%95%EA%B7%9C%ED%99%94_%EB%B0%A9%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***다른 정규화 방법들***

# %% [markdown]
# ## 1. 더 많은 데이터를 사용
#   도움은 줄 수 있으나 많은 비용이 들거나 불가능한 경우가 있다.
#
# 하지만 데이터를 좌우 반전(수평방향 뒤집기)나 회전 확대등으로 데이터를 늘릴 수는 있지만 이렇게 중복된 데이터가 많아지면 좋지않다!
#
# 그러나 새 데이터를 구하지 않고 할 수있는 방법

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 하지만 새 데이터를 가져와서 집어넣는 것보다 더 많은 정보를 추가해주지 못한다
#
# 다만 이 방법을 통해서도 정규화를 하고 과대적합을 줄일 수 있다!
#
# 이렇게 변형해도 여전히 고양이라는걸 인지 시킬 수 있음
#
# 즉 고양이라고 인지 못하는 그럼 변형을 주어서는 안된다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 숫자에 대한 무작위 왜곡과 회전
#
# 왜곡을 줄 때 미묘하게 왜곡시키면 된다, 너무 큰 왜곡은 필요없다
#
# 여기 4들은 한눈에 알 수 있게 좀 크게 왜곡된 것들

# %% [markdown]
# ## 2. 조기 종료

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# train error나 비용함수 j가 다음과 같이 단조 감소하는 형태를 보이고
#
# Dev error도 단조 감소를 보여아하는데 도중에 증가할 때가 있다
#
# train data 과대적합이 이뤄지는 시기이므로 이 점을 기준으로 학습을 종료하는 기법!

# %% [markdown]
# 신경망에서 많은 반복을 실행시키지 않은 경우 w 값이 0에 가까움
#
# 너무 많이 실행하면 w가 매우 커지게 되므로
#
# w가 중간크기를 갖는 부분을 찾아 종료하는 것

# %% [markdown]
# > 단점
#
# 머신러닝 과정은 서로 다른 몇 가지 단계로 이루어지는데
#
# 1. 비용함수 j를 최적화하는 알고리즘이 필요! > 많은 알고리즘에서 찾아야함
#  - 경사하강법과 같은 몇가지 알고리즘
#  - 이 단계는 분산을 줄이는 단계
#
# 2. 과대적합(Overfitting) 막기
#  - 정규화, 데이터 추가
#
# 각각 단계는 직교화(하나의 단계가 하나의 문제를 해결)하는 모습을 보이는데
#
# 조기 종료의 단점은 이 둘을 섞어버리면서 나타나게 되는데 이 두 문제에 대해서 더 이상 독립적으로 작업할 수 없게 된다는 점

# %% [markdown]
# 조기 종료를 하면서 비용함수 J를 최적화하는 것을 멈추게 되므로 비용함수를 제대로 못 줄이는 문제가 발생함과 동시에 과대적합을 막으려고 함
#
# 하이퍼피라미터의 탐색 공간이 겹치게 되면서 어려워짐!
#
# > 조기 종료의 대안으로는 L2 정규화를 사용하는 방법이 있다.
#  이 방법으로 조금 더 오래 학습을 진행할 수 있게 된다!
#  - 그러나 정규화 매개변수 람다에 많은 값을 시도해봐야함, 람다에 많은 값을 대입하는 것은 컴퓨터적으로 비용이 많이듬

# %% [markdown]
# 이러한 단점에도 불구하고 조기종료를 많이 사용하게 되는데 그 이유는 W값을 작은 값 중간 값 큰 값을 얻을 수 있기 때문!
#
# 하지만 앤드류 교수님은 L2 정규화 기법을 사용해 람다에 많은 값을 시도하는 방법을 선호합니다.
#
# - 컴퓨터가 감당할 수만 있다면...
#
# >조기 종료를 잘 이용하면 람다값을 넣는 과정 없이 비슷한 효과를 얻을 수 있습니다.
