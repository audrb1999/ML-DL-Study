# %% [markdown]
# <a href="https://colab.research.google.com/github/audrb1999/ML-DL-Study/blob/main/%EC%8B%AC%EC%B8%B5%20%EC%8B%A0%EA%B2%BD%EB%A7%9D%20%EC%84%B1%EB%8A%A5%20%ED%96%A5%EC%83%81%EC%8B%9C%ED%82%A4%EA%B8%B0/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%20%EC%96%B4%ED%94%8C%EB%A6%AC%EC%BC%80%EC%9D%B4%EC%85%98%20%EC%84%A4%EC%A0%95%ED%95%98%EA%B8%B0/31_%EC%A7%80%EC%97%AD_%EC%B5%9C%EC%A0%81%EA%B0%92_%EB%AC%B8%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #지역 최적값 문제

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 여기서 높이가 오차값, 정가운데 있는 글로벌 최적값에 가기전에 지역 최솟값에 머물 확률이 높아짐!
#
# > 고차원 함수 볼록볼록함

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 낮은 차원의 그림으로 그린다면 경사가  0인점은 대부분은 최소값이 아닌 대개 안장점입니다.
#
# > 말 모양과 같아서 안장점

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 낮은 차원에서 얻은 직관이 항상 높은 차원에서 돌아갈 때 적용되지 않을 수 있다는 것

# %% [markdown]
# 안장점, 안정점에 가면 로컬 미니멈에 빠져서 움직이질 못함
#
# 이럴땐 왼쪽이나 오른쪽에 작은 변화를 주면 빠져나갈 수 있습니다.
