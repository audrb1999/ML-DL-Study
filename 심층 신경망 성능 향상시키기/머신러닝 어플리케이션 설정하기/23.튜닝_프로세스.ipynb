# %% [markdown]
# <a href="https://colab.research.google.com/github/audrb1999/ML-DL-Study/blob/main/%EC%8B%AC%EC%B8%B5%20%EC%8B%A0%EA%B2%BD%EB%A7%9D%20%EC%84%B1%EB%8A%A5%20%ED%96%A5%EC%83%81%EC%8B%9C%ED%82%A4%EA%B8%B0/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%20%EC%96%B4%ED%94%8C%EB%A6%AC%EC%BC%80%EC%9D%B4%EC%85%98%20%EC%84%A4%EC%A0%95%ED%95%98%EA%B8%B0/%ED%8A%9C%EB%8B%9D_%ED%94%84%EB%A1%9C%EC%84%B8%EC%8A%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 튜닝 프로세스

# %% [markdown]
# 학습을 할 때 많은 하이퍼 파라미터를 사용하는데 그럼 좋은 하이퍼 파라미터는 어떻게 찾을 수 있을까?
#
#
# - 1. 학습률 $\alpha$
#
# - 2. 모멘텀을 나타내는 $\beta$(기본값 0.9)
#
# - Adam에서 사용하는 $\beta_1$, $\beta_2$, $\epsilon$
#
# - 3. layer 갯수
#
# - 2. 은닉 유닛의 숫자
#
# - 3. 학습률을 그냥 쓰지않고 학습률 감쇠랑 같이 쓰면 learing rate decay 값
#
# - 2. 미니 배치의 크기
#
#
# > 하이퍼 파라미터에도 중요도가 있는데 순위를 매겨보자면 > 앞에 숫자가 1이면 젤 중요 내려 갈 수록 점점 중요도가 떨어짐
#
# 완벽하게 알맞지는 않음!

# %% [markdown]
# 머신러닝 초기에는 하이퍼 파라미터 튜닝을(하이퍼 파라미터 2개가 있다고 할 떄)
#
#
# - Hyperparameter1, 2
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 1번째는 머신러닝 방법으로 격자식으로 값들을 나눠서 하나 씩 적용해봄
#
# - 2번째는 딥러닝 방식으로 무작위로 선택해서 좋은 값을 찾아봄
#
#
# 이렇게 하는 이유는 어떤 하이퍼 파라미터가 문제 해결에 더 중요한지 미리 알 수 없기 떄문입니다.

# %% [markdown]
# 1번째에서 1 = 학습률, 2 = 앱실론이라고 하면 학습률이 전반적인 성능을 정하기 때문에 앱실론에 상관없이 학습률이 젤 높은 끝 부분 다섯 개의 결과가 같음
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 이러면 25개의 모델을 학습했지만 가장 중요한 학습률 다섯 개에 대해서만 학습시킨 것과 다를 게 없습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 이런 식으로 일정하게 변화하기에 다양성이 떨어지게 됩니다.

# %% [markdown]
# 반대로 랜덤식이면
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 위와 같이 똑같이 25개의 모델을 훈련했지만 여기서는 학습률값이 다양하게 바뀌면서 더 좋은 하이퍼 파라미터를 찾을 확률이 높아집니다.

# %% [markdown]
# 여기서 하이퍼 파라미터가 더 많아진다면 (3개를 예시로 들자면)
#
# 정사각형이 아니라 정육면체를 탐색하는게 됩니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 실제로 3개 보다 더 많은 하이퍼 피라미터를 탐색합니다. 어떤 하이퍼 피라미터가 가장 중요한지 미리 알기 어렵습니다.

# %% [markdown]
# ## 정밀화 접근
#
# 다른 일반적인 방법!

# %% [markdown]
# 랜덤으로 값을 주다가 파란색 원들이 모여있는 곳이 성능이 높게 나왔습니다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 그러면 그 부분을 확대해서 그 부분에서 다시 랜덤값을 주는 과정을 진행합니다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 더 조밀하게 값을 갱신하면서 최고의 하이퍼 파라미터가 있는 영역에서 값을 찾아갑니다.
#
# 다시 더 높은 성능을 보이는 부분을 찾았다면 그 부분을 확대해서 거기서 무작위 값을 넣는 과정을 진행합니다.

# %% [markdown]
# 정리
#
# 1. 격자점이 아닌 무작위 점이다
#
# 2. 원한다면 정밀화 접근을 이용할 수 있다
