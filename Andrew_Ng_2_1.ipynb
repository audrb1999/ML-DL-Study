# %% [markdown]
# <a href="https://colab.research.google.com/github/audrb1999/ML-DL-Study/blob/main/Andrew_Ng_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# >배울 내용들
#
# 1. 데이터를 설정하기 위한 하이퍼피라매터 튜닝
# 2. 최적화 알고리즘의 속도를 높여 적당한 시간 안에 학습

# %% [markdown]
# #***1. 머신러닝 문제 해결 방법***
# > 정규화를 배우고 신경망이 제대로 구현됬는지 확인하는 과정

# %% [markdown]
# 훈련시킬 때 내려야하는 과정들
#
# 1. 신경망이 몇 개의 층을 가지는지, 각각의 층이 몇 개의 은닉 유닛을 가지는지
#
# 2. 학습률 정하기
#
# 3. 올바른 활성화 함수 정하기

# %% [markdown]
# 아무리 조예가 깊다고 해도 한번에 알맞은 하이퍼 피라매터를 찾는 건 거의 불가능!
#
# 좋은 선택을 하기위해 여러번 사이클을 돌려야하며 중요한 건 이 사이클을 얼마나 효율적으로 돌 수 있는지 데이터 세트를 잘 설정하는 것!

# %% [markdown]
# ![train_test.PNG](data:image/png;base64,...)

# %% [markdown]
# 이미지 출처 : https://en.wikipedia.org/wiki/Training,_validation,_and_test_sets

# %% [markdown]
# B에서 1번째 2번째 데이터 셋으로 해당 문제에 대해 효율적인 모델을 찾고 추가적으로 더 발전시키고 싶은 모델을 뽑아 Test set을 적용시키는 것!

# %% [markdown]
# ---
#
#
# 머신러닝 시대에는 (데이터가 대략 몇 백 ~ 몇 만단위)
# 데이터가 적을 때 유용한 방법
#
# 1. train 70, test 30
# 2. train 60, validation 20, test 20 이렇게 많이 사용
#
#
#
# ---
#
#
#
# 현재 빅데이터 시대에서는 개발 세트와 테스트 세트가 훨씬 더 작은 비율이 되는 것이
# 트렌드!
#
# 왜냐하면 개발 세트와 테스트 세트의 목표는 서로 다른 알고리즘을 시험하고 어떤 알고리즘이 더 잘 작동하는지 확인하는 용도이기에 빠르게 평가할 수 있는 크기가 좋음!

# %% [markdown]
# 총 백 만개의 데이터가 있다면 만 개의 데이터로도 충분히 평가가 가능함! > validiation
#
# test set은 최종 분류기가 어느 정도 성능인지 신뢰있는 추정치를 제공하는 역할이기에 똑같이 만 개의 샘플로도 가능!

# %% [markdown]
# 왠만해서는 데이터들은 같은 분포에서 가져오는게 좋음!
