# %% [markdown]
# <a href="https://colab.research.google.com/github/audrb1999/ML-DL-Study/blob/main/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%20%EA%B5%AC%EC%A1%B0%ED%99%94%ED%95%98%EA%B8%B0/4.%20%EC%B5%9C%EC%A0%81%ED%99%94_%EC%B2%99%EB%8F%84_%EB%A7%8C%EC%A1%B1%EC%8B%9C%ED%82%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #최적화 척도 만족시키기

# %% [markdown]
# 최적의 기준을 세우는 방법을 배워보자!

# %% [markdown]
# 우리가 중요하게 생각하는 모든 기준을 하나의 실수 평가 기준으로 합치는 것은 쉽지 않은 일입니다.  하지만 만족스러운 최적의 기준을 세우는 것이 쓸모가 많습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 다음은 분류기인데요 다음과 같이 정확도와 실행 시간이 있습니다.
#
# 전체적인 평가 기준에 정확도와 실행 시간을 결합할 수 있습니다. > 전체 비용
#
# 1. acc - 0.5 * runningtime  이렇게 0.5 > 실행 시간과 정확도를 선형적으로 합치면 인위적이게 됩니다.
#
# 2. 정확도가 최고인 모델을 고르면서 실행 시간이 100ms 이하인 모델을 고르기 이렇게 선택하는 것이 좋을 수 도 있습니다.
#    - 여기서 정확도를 최적화 척도라고 합니다.
#    - 왜냐하면 최대의 정확도를 원하기 때문입니다.
#    - 실행시간은 조건 척도라고 합니다. 어떤 조건만 만족하면 된다는 의미죠.
#    - 100ms 이하라면 그것보다 좋아도 50ms든지 100ms든지 똑같이 생각한다는 것!
#    - 트레이드 정확도와 실행시간을 결합시켰을 때와 비교해서 트레이드오프가 존재합니다.

# %% [markdown]
# n개의 척도가 고려된다고 할 때 하나의 최적 척도로 골라서 가능한 성능을 높이고 싶고 n-1개를 조건 척도로 둬서 그 기준을 너기만 하면 성능이 얼마나 좋든지 상관이 없다는 것입니다.

# %% [markdown]
# 만약 인공지능 스피커에 대해서 생각해보면 24시간 진행되는데 음성응답을 24시간 동안 1회 거짓 양성이 나와야된다 같은 조건

# %% [markdown]
# 1. 성능을 최대로 높이고 싶은 하나를 최적 척도를 하나를 정하고 어떤 기준만 넘기면 되도록 하나 이상을 조건 척도로 정함으로 거의 자동으로 여러 분류기를 살핀 뒤 빠르게 최고를 선별할 수 있습니다.
