# %% [markdown]
# <a href="https://colab.research.google.com/github/audrb1999/ML-DL-Study/blob/main/%EB%B0%91%EB%94%A51/2.%ED%8D%BC%EC%85%89%ED%8A%B8%EB%A1%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2.퍼셉트론
#
# - 다수의 신호를 입력으로 받아 하나의 신호로 출력

# %% [markdown]
# 입력이 2개인 퍼셉트론의 예
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 각 입력 신호에 가중치를 곱하고 그 값들을 더해서 한계값을 넘어설 때만 1을 출력합니다.
#
# $y = 0$일 때 $(w_1x_1 + w_1x_2 \leq \theta)$
#
#
#
# $y = 1$일 때 $ (w_1x_1 + w_1x_2 > \theta)$

# %% [markdown]
# 가중치는 각 신호가 결과에 주는 영향력을 조절하는 요소입니다.
#
# 가중치가 클수록 해당 신호가 그만큼 더 중요하다는 의미입니다.

# %% [markdown]
# ## 2.3 퍼셉트론 구현하기

# %% [markdown]
# ### 2.3.1 간단한 구현

# %%
def AND(x1, x2):
    w1, w2, theta = 0.5, 0.5, 0.7
    tmp = x1*w1 + x2*w2
    if tmp <= theta:
        return 0
    elif tmp > theta:
        return 1

# %%
# 실험해보기

print(AND(0, 0), '\n')
print(AND(1, 0), '\n')
print(AND(0, 1), '\n')
print(AND(1, 1), '\n')
# Out:
# 0
#
# 0
#
# 0
#
# 1

# %% [markdown]
# ### 2.3.2 가중치와 편향 도입

# %% [markdown]
# $y = 0$일 때 $(w_1x_1 + w_1x_2 + b \leq 0)$
#
# $y = 1$일 때 $ (w_1x_1 + w_1x_2 +b > 0)$
#
# <br>
#
# > $\theta$를 $-b$로 치환하면 다음과 같이 표현이 가능합니다.

# %%
import numpy as np
x = np.array([0, 1])
w = np.array([0.5, 0.5])
b = -0.7
np.sum(w*x) + b
# Out:
# -0.19999999999999996

# %% [markdown]
# ### 2.3.2 가중치와 편향 도입

# %% [markdown]
# AND에 편향을 도입해보자

# %%
def AND(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = -0.7
    
    tmp = np.sum(w*x) + b 
    if tmp <= 0:
        return 0
    elif tmp > 0:
        return 1

# %% [markdown]
# NAND와 OR게이트 구현

# %%
def NAND(x1, x2):
    x = np.array([x1, x2])
    w = np.array([-0.5, -0.5])# AND에서 가중치만 -로 변환
    b = 0.7

    tmp = np.sum(w*x) + b 
    if tmp <= 0:
        return 0
    else: return 1

def OR(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = -0.2 # 두 개중 하나만 값을 가져도 임계값을 넘게 설정

    tmp = np.sum(w*x) + b 
    if tmp <= 0:
        return 0
    else: return 1

# %% [markdown]
# ## 2.4 퍼셉트론의 한계

# %% [markdown]
# ###2.4.1 도전 XOR 게이트
#
# > 베타적 논리합으로 입력값이 서로 다를 때만 1이 출력됨!

# %% [markdown]
# 하나의 게이트만으로는 (선형 결정 분리로는) 불가능한 문제!
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2.5.2  XOR 게이트 구현하기
#
# 다층 퍼셉트론으로 OR, NAND, AND를 쌓으면 해결할 수있다.

# %%
def XOR(x1, x2):
    s1 = NAND(x1, x2)
    s2 = OR(x1, x2)
    y = AND(s1, s2)
    return y

# %%
print(XOR(0, 0))
print(XOR(1, 0))
print(XOR(0, 1))
print(XOR(1, 1))
# Out:
# 0
# 1
# 1
# 0

# %% [markdown]
# 활성화 함수를 사용하지않아도 층을 쌓아 비선형을 만들 수 있다!
#
# - 이번장 정리
#
# ![image.png](data:image/png;base64,...)
